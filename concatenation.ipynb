# %%
import pandas as pd

path = "data/cleaned/"
articles = pd.read_csv(path + 'articles.csv', index_col="Unnamed: 0")
life_situations = pd.read_csv(path + 'life_situations.csv', index_col="Unnamed: 0")
news = pd.read_csv(path + 'news.csv', index_col="Unnamed: 0")
services = pd.read_csv(path + 'services.csv', index_col="Unnamed: 0")

# %%
def concat_text_columns(df, columns):
    df = df.copy()
    df['text'] = df[columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
    df['text'] = df['text'].str.replace('nan ', '').str.replace(' nan ', '').str.replace(' nan', '')
    df = df.drop(columns=columns)
    return df

# %%
articles_concat = concat_text_columns(articles, ['title', 'content'])
articles_concat
# Out:
#        true_id      id sys_lang                 projects  \
# 0         2884  135747       ru    departament-kkbtu-sko
# 1         2885  119917       ru            kgd-karaganda
# 2         2886    8414       ru  turkestan-tolebi-audany
# 3         2887  118430       kk                  qazalem
# 4         2888    5319       kk            kyzylorda-kzo
# ...        ...     ...      ...                      ...
# 99995   102879   23291       ru                   sko-gm
# 99996   102880   55210       ru                  kgd-sko
# 99997   102881  111387       kk              adilet-abai
# 99998   102882  124183       ru             abay-tabigat
# 99999   102883   72773       kk                 emer-alm
#
#                                                      url  \
# 0      https://www.gov.kz/memleket/entities/departame...
# 1      https://www.gov.kz/memleket/entities/kgd-karag...
# 2      https://www.gov.kz/memleket/entities/turkestan...
# 3      https://www.gov.kz/memleket/entities/qazalem/p...
# 4      https://www.gov.kz/memleket/entities/kyzylorda...
# ...                                                  ...
# 99995  https://www.gov.kz/memleket/entities/sko-gm/pr...
# 99996  https://www.gov.kz/memleket/entities/kgd-sko/p...
# 99997  https://www.gov.kz/memleket/entities/adilet-ab...
# 99998  https://www.gov.kz/memleket/entities/abay-tabi...
# 99999  https://www.gov.kz/memleket/entities/emer-alm/...
#
#                                                     text
# 0      Бешенство – смертельная угроза для человека! Б...
# 1      Порядок администрирования налога на транспортн...
# 2      Спорт Миссия: формирование единой государствен...
# 3      ҚАЗАҚСТАННЫҢ МЕМЛЕКЕТТІК ОРГАНДАРЫМЕН БАЙЛАНЫС...
# 4      2022 жылға жергілікті атқарушы органдармен сыб...
# ...                                                  ...
# 99995  Разъяснение антикоррупционного законодательств...
# 99996  Статистические данные по оказанным государстве...
# 99997  Адвокаттық қызмет Адвокаттық қызмет – адвокатт...
# 99998  Заявление о намечаемой деятельности по объекту...
# 99999  Жер сілкінісі туралы ақпарат ҚР ТЖМ Сейсмологи...
#
# [96556 rows x 6 columns]

# %%
life_situations_concat = concat_text_columns(life_situations, ['intro', 'title_main', 'title_sub'])
life_situations_concat
# Out:
#       true_id   id sys_lang  subid  \
# 0      202884   62       en    245
# 1      202885   62       en    246
# 2      202886   62       en    248
# 3      202887   62       en    247
# 4      202888   62       en    249
# ...       ...  ...      ...    ...
# 4403   207287  225       kk    618
# 4404   207288  225       kk    619
# 4405   207289  225       kk    621
# 4406   207290  225       kk    623
# 4407   207291  225       kk    622
#
#                                             instruction  \
# 0     Для установления инвалидности сначала нужно об...
# 1     Освидетельствование проводится по заявлению на...
# 2     В зависимости от степени нарушения функций орг...
# 3     Датой установления инвалидности, степени утрат...
# 4     Инвалидность устанавливается на следующие срок...
# ...                                                 ...
# 4403  Zhumys orny men laýazymyn saqtaý, úzdiksiz eńb...
# 4404  Magistratýranyń bilim berý baǵdarlamalary: Oqý...
# 4405  Memlekettik qyzmetshiler bolyp tabylatyn Qazaq...
# 4406  Test tildik tórt daǵdy boiynsha tapsyrmalardan...
# 4407  Eger Siz memlekettik qyzmetshi bolmasańyz, bir...
#
#                                                    URL  \
# 0      https://beta2.egov.kz/situations/62/245?lang=en
# 1      https://beta2.egov.kz/situations/62/246?lang=en
# 2      https://beta2.egov.kz/situations/62/248?lang=en
# 3      https://beta2.egov.kz/situations/62/247?lang=en
# 4      https://beta2.egov.kz/situations/62/249?lang=en
# ...                                                ...
# 4403  https://beta2.egov.kz/situations/225/618?lang=kk
# 4404  https://beta2.egov.kz/situations/225/619?lang=kk
# 4405  https://beta2.egov.kz/situations/225/621?lang=kk
# 4406  https://beta2.egov.kz/situations/225/623?lang=kk
# 4407  https://beta2.egov.kz/situations/225/622?lang=kk
#
#                                                    text
# 0     Инвалиды – это лица, которые из-за стойких рас...
# 1     Инвалиды – это лица, которые из-за стойких рас...
# 2     Инвалиды – это лица, которые из-за стойких рас...
# 3     Инвалиды – это лица, которые из-за стойких рас...
# 4     Инвалиды – это лица, которые из-за стойких рас...
# ...                                                 ...
# 4403  Қазақстан Республикасы Президенті жанындағы Ме...
# 4404  Қазақстан Республикасы Президенті жанындағы Ме...
# 4405  Қазақстан Республикасы Президенті жанындағы Ме...
# 4406  Қазақстан Республикасы Президенті жанындағы Ме...
# 4407  Қазақстан Республикасы Президенті жанындағы Ме...
#
# [4408 rows x 7 columns]

# %%
news_concat = concat_text_columns(news, ['title', 'body', 'short_description'])
news_concat
# Out:
#        true_id      id sys_lang                    projects  \
# 0       102884  117143       qq                   mangystau
# 1       102885  432491       ru                vko-glubokoe
# 2       102886  563257       qq  turkestan-shardarin-audany
# 3       102887  591387       ru                  mvd-almaty
# 4       102888  312155       kk                      almaty
# ...        ...     ...      ...                         ...
# 99995   202879  367308       kk         borodulihamaslikhat
# 99996   202880  589811       qq             maslihat-almaty
# 99997   202881  259111       en              mfa-bratislava
# 99998   202882  592904       ru                  abay-bilim
# 99999   202883  276075       kk                aqmola-akkol
#
#                                                      url  \
# 0      https://www.gov.kz/memleket/entities/mangystau...
# 1      https://www.gov.kz/memleket/entities/vko-glubo...
# 2      https://www.gov.kz/memleket/entities/turkestan...
# 3      https://www.gov.kz/memleket/entities/mvd-almat...
# 4      https://www.gov.kz/memleket/entities/almaty/pr...
# ...                                                  ...
# 99995  https://www.gov.kz/memleket/entities/borodulih...
# 99996  https://www.gov.kz/memleket/entities/maslihat-...
# 99997  https://www.gov.kz/memleket/entities/mfa-brati...
# 99998  https://www.gov.kz/memleket/entities/abay-bili...
# 99999  https://www.gov.kz/memleket/entities/aqmola-ak...
#
#                                                     text
# 0      MAŃǴYSTAÝDA I ZhÁNE II DEŃGEILI INFEKTsIIaLYQ ...
# 1      Что необходимо знать избирателю? 20 ноября 202...
# 2      FÝTBOL ZhARYSY UIYMDASTYRYLDY. Zhastar arasynd...
# 3      ДП Алматы: ежедневно общественный порядок в го...
# 4      Б. Сағынтаев ҰҚШҰ Ұжымдық бітімгершілік күштер...
# ...                                                  ...
# 99995  Аудандық мәслихаттың хатшысы, «Аманат» партияс...
# 99996  Almaty qalasy Máslihaty depýtattarynyń qoǵamdy...
# 99997  Strengthening scientific research cooperation ...
# 99998  Сообщать о коррупции очень важно Антикоррупцио...
# 99999  Аудан әкімінің м. а  техникалық кеңес абаттанд...
#
# [98355 rows x 6 columns]

# %%
services_concat = concat_text_columns(services, ['additional_info', 'description', 'full_title', 'result_description'])
services_concat = services_concat.drop(columns=['short_title', 'title'])
services_concat
# Out:
#       true_id    id sys_lang                                          url  \
# 0           0  3087       en  https://beta2.egov.kz/services/3087?lang=en
# 1           1  3081       en  https://beta2.egov.kz/services/3081?lang=en
# 4           4  3811       en  https://beta2.egov.kz/services/3811?lang=en
# 5           5  3263       en  https://beta2.egov.kz/services/3263?lang=en
# 6           6  3040       en  https://beta2.egov.kz/services/3040?lang=en
# ...       ...   ...      ...                                          ...
# 2835     2835  4149       qq  https://beta2.egov.kz/services/4149?lang=qq
# 2867     2867  3570       qq  https://beta2.egov.kz/services/3570?lang=qq
# 2868     2868  4724       ru  https://beta2.egov.kz/services/4724?lang=ru
# 2869     2869  4725       ru  https://beta2.egov.kz/services/4725?lang=ru
# 2883     2883  4182       qq  https://beta2.egov.kz/services/4182?lang=qq
#
#                                                    text
# 0     Rules for providing state services Dear citize...
# 1     Rules for providing state services Information...
# 4     Information is being updated. What is Personal...
# 5     Rules for providing state services Information...
# 6     Rules for providing state services Dear citize...
# ...                                                 ...
# 2835  Aqparat ózektendirý satysynda. Úshinshi tulǵal...
# 2867  Memlekettik qyzmet kórsetý erezhesi Qurmetti Q...
# 2868  Возмещение затрат на повышение компетенции раб...
# 2869  Возмещение затрат на повышение эффективности о...
# 2883  Memlekettik qyzmet kórsetý erezhesi Aqparat óz...
#
# [2634 rows x 5 columns]

# %%
# save it into concated folder
path = "data/concated/"
articles_concat.to_csv(path + 'articles.csv')
life_situations_concat.to_csv(path + 'life_situations.csv')
news_concat.to_csv(path + 'news.csv')
services_concat.to_csv(path + 'services.csv')
